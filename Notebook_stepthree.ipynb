# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import datetime
import seaborn as sns
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\javie\\OneDrive\\Documents\\jupyter_notebooks\\guided capstone'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
df = pd.read_csv('data/step2_output.csv', index_col='Unnamed: 0')
df.head(5)
# Out:
#                   Name   Region    state  summit_elev  vertical_drop  \
# 0       Alyeska Resort   Alaska   Alaska         3939           2500
# 1  Eaglecrest Ski Area   Alaska   Alaska         2600           1540
# 2     Hilltop Ski Area   Alaska   Alaska         2090            294
# 3     Arizona Snowbowl  Arizona  Arizona        11500           2300
# 4  Sunrise Park Resort  Arizona  Arizona        11100           1800
#
#    base_elev  trams  fastEight  fastSixes  fastQuads  ...  LongestRun_mi  \
# 0        250      1        0.0          0          2  ...            1.0
# 1       1200      0        0.0          0          0  ...            2.0
# 2       1796      0        0.0          0          0  ...            1.0
# 3       9200      0        0.0          1          0  ...            2.0
# 4       9200      0        0.0          0          1  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0      550.000000
# 1      100.395722
# 2       30.000000
# 3      100.395722
# 4       80.000000
#
# [5 rows x 27 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.820789     1.845918    1.0     2.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   174.873239   242.378848    2.0    55.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.656535   109.263494    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   120.053004    28.742976   30.0   101.25
# NightSkiing_ac     330.0   100.395722    79.076753    2.0    60.00
#
#                            50%          75%      max
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.820789     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac      132.500000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   120.053004   136.000000    305.0
# NightSkiing_ac      100.395722   100.395722    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               330 non-null    object
#  1   Region             330 non-null    object
#  2   state              330 non-null    object
#  3   summit_elev        330 non-null    int64
#  4   vertical_drop      330 non-null    int64
#  5   base_elev          330 non-null    int64
#  6   trams              330 non-null    int64
#  7   fastEight          330 non-null    float64
#  8   fastSixes          330 non-null    int64
#  9   fastQuads          330 non-null    int64
#  10  quad               330 non-null    int64
#  11  triple             330 non-null    int64
#  12  double             330 non-null    int64
#  13  surface            330 non-null    int64
#  14  total_chairs       330 non-null    int64
#  15  Runs               330 non-null    float64
#  16  TerrainParks       330 non-null    float64
#  17  LongestRun_mi      330 non-null    float64
#  18  SkiableTerrain_ac  330 non-null    float64
#  19  Snow Making_ac     330 non-null    float64
#  20  daysOpenLastYear   330 non-null    float64
#  21  yearsOpen          330 non-null    float64
#  22  averageSnowfall    330 non-null    float64
#  23  AdultWeekday       330 non-null    float64
#  24  AdultWeekend       330 non-null    float64
#  25  projectedDaysOpen  330 non-null    float64
#  26  NightSkiing_ac     330 non-null    float64
# dtypes: float64(13), int64(11), object(3)
# memory usage: 72.2+ KB

# %%
df['trams'] = df['trams'].astype(float)
df['fastEight'] = df['fastEight'].astype(float)
df['fastSixes'] = df['fastSixes'].astype(float)

df['trams'].nunique(), df['fastEight'].nunique(), df['fastSixes'].nunique()
# Out:
# (5, 2, 7)

# %%
# selecting columns with numerical values
df.hist(bins=25, figsize=(30, 20))
plt.show()

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions! 
f, ax = plt.subplots(figsize=(10, 10))

x = pd.DataFrame(df.Region.value_counts())

names = list(x.index)

values = list(x.Region)

sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
df.drop('Region', 1, inplace=True)

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
df.plot(kind='box', subplots=True, layout=(10, 4), figsize=(20, 60))
plt.show()

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = df.quantile(0.75)

# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3 - Q1

# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = df[~((df < (Q1 - 1.5 * IQR)) | (df> (Q3 + 1.5 * IQR))).any(axis=1)]

# We now want to make a boxplot of this new dataframe dfno. 
dfno_boxplot = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
dfno.shape
# Out:
# (165, 26)

# %%
dfno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 2 to 329
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               165 non-null    object
#  1   state              165 non-null    object
#  2   summit_elev        165 non-null    int64
#  3   vertical_drop      165 non-null    int64
#  4   base_elev          165 non-null    int64
#  5   trams              165 non-null    float64
#  6   fastEight          165 non-null    float64
#  7   fastSixes          165 non-null    float64
#  8   fastQuads          165 non-null    int64
#  9   quad               165 non-null    int64
#  10  triple             165 non-null    int64
#  11  double             165 non-null    int64
#  12  surface            165 non-null    int64
#  13  total_chairs       165 non-null    int64
#  14  Runs               165 non-null    float64
#  15  TerrainParks       165 non-null    float64
#  16  LongestRun_mi      165 non-null    float64
#  17  SkiableTerrain_ac  165 non-null    float64
#  18  Snow Making_ac     165 non-null    float64
#  19  daysOpenLastYear   165 non-null    float64
#  20  yearsOpen          165 non-null    float64
#  21  averageSnowfall    165 non-null    float64
#  22  AdultWeekday       165 non-null    float64
#  23  AdultWeekend       165 non-null    float64
#  24  projectedDaysOpen  165 non-null    float64
#  25  NightSkiing_ac     165 non-null    float64
# dtypes: float64(15), int64(9), object(2)
# memory usage: 34.8+ KB

# %%
df.shape
# Out:
# (330, 26)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
dfno.hist('AdultWeekday', grid=False, bins=25)
plt.xlabel('Day entrance price')
plt.ylabel('# of resorts')
plt.show()

# %%
# Do the same but with the AdultWeekend column 
dfno.hist('AdultWeekend', grid=False, bins=25)
plt.xlabel('Day entrance price')
plt.ylabel('# of resorts')
plt.show()

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :) 
dfno.hist('daysOpenLastYear', grid=False, bins=25)
plt.xlabel('Open days')
plt.ylabel('# of resorts')
plt.show()

# %%
dfno.hist('projectedDaysOpen', grid=False, bins=25)
plt.xlabel('Projected open days')
plt.ylabel('# of resorts')
plt.show()

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
comp_dfno = dfno[['AdultWeekday', 'AdultWeekend', 'daysOpenLastYear', 'projectedDaysOpen']]
comp_dfno.head(5)
# Out:
#     AdultWeekday  AdultWeekend  daysOpenLastYear  projectedDaysOpen
# 2      30.000000      34.00000        150.000000              152.0
# 4      74.000000      78.00000        115.000000              104.0
# 5      47.000000      47.00000        110.000000              107.0
# 10     75.000000      75.00000        163.000000              170.0
# 12     57.916957      64.16681        115.103943              128.0

# %%
pair_plot = sns.pairplot(comp_dfno)

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\javie\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\javie\anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\javie\anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col6 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col9 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col11 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col12 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col13 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col14 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col15 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col16 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col17 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col19 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col20 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col21 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col22 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow0_col23 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col6 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col9 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col10 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col11 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col12 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col13 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col14 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col15 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col16 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col17 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col18 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col19 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col20 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col21 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col22 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow1_col23 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col1 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col8 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col9 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col10 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_4abf7ff4_cb90_11ea_9616_a0ceda77f56frow2_col11 {
#             background-color:  #3b4cc0;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (165, 25)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop('base_elev', axis=1)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno['clusters'] = y_kmeans3
dfno.head(5)
# Out:
#                              Name       state  summit_elev  vertical_drop  \
# 2                Hilltop Ski Area      Alaska         2090            294
# 4             Sunrise Park Resort     Arizona        11100           1800
# 5   Yosemite Ski & Snowboard Area  California         7800            600
# 10               Donner Ski Ranch  California         8012            750
# 12                  June Mountain  California        10090           2590
#
#     trams  fastEight  fastSixes  fastQuads  quad  triple  ...  \
# 2     0.0        0.0        0.0          0     0       1  ...
# 4     0.0        0.0        0.0          1     2       3  ...
# 5     0.0        0.0        0.0          0     0       1  ...
# 10    0.0        0.0        0.0          0     0       1  ...
# 12    0.0        0.0        0.0          2     0       0  ...
#
#     SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 2                30.0       30.000000        150.000000       36.0
# 4               800.0       80.000000        115.000000       49.0
# 5                88.0      174.873239        110.000000       84.0
# 10              505.0       60.000000        163.000000       82.0
# 12             1500.0      174.873239        115.103943       58.0
#
#     averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 2              69.0     30.000000      34.00000              152.0
# 4             250.0     74.000000      78.00000              104.0
# 5             300.0     47.000000      47.00000              107.0
# 10            400.0     75.000000      75.00000              170.0
# 12            250.0     57.916957      64.16681              128.0
#
#     NightSkiing_ac  clusters
# 2        30.000000         0
# 4        80.000000         1
# 5       100.395722         1
# 10      100.395722         1
# 12      100.395722         1
#
# [5 rows x 26 columns]

# %%
# Write your dataframe to csv 
dfno.to_csv('data/step3_output.csv')

# %% [markdown]
# <font color='red'>**In the following cells I will perform the same operations but including outliers and export in a different csv file.**</font>

# %%
# I will remove by hand problematic rows observed in the box plots above

df = df[df['SkiableTerrain_ac'] < 8000]
df = df[df['Snow Making_ac'] < 1400]
df = df[df['daysOpenLastYear'] < 300]
df = df[df['daysOpenLastYear'] > 14]
df = df[df['projectedDaysOpen'] < 300]
df = df[df['yearsOpen'] < 200]
df = df[df['Runs'] < 200]
df.drop('fastEight', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 0 to 329
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               320 non-null    object
#  1   state              320 non-null    object
#  2   summit_elev        320 non-null    int64
#  3   vertical_drop      320 non-null    int64
#  4   base_elev          320 non-null    int64
#  5   trams              320 non-null    float64
#  6   fastSixes          320 non-null    float64
#  7   fastQuads          320 non-null    int64
#  8   quad               320 non-null    int64
#  9   triple             320 non-null    int64
#  10  double             320 non-null    int64
#  11  surface            320 non-null    int64
#  12  total_chairs       320 non-null    int64
#  13  Runs               320 non-null    float64
#  14  TerrainParks       320 non-null    float64
#  15  LongestRun_mi      320 non-null    float64
#  16  SkiableTerrain_ac  320 non-null    float64
#  17  Snow Making_ac     320 non-null    float64
#  18  daysOpenLastYear   320 non-null    float64
#  19  yearsOpen          320 non-null    float64
#  20  averageSnowfall    320 non-null    float64
#  21  AdultWeekday       320 non-null    float64
#  22  AdultWeekend       320 non-null    float64
#  23  projectedDaysOpen  320 non-null    float64
#  24  NightSkiing_ac     320 non-null    float64
# dtypes: float64(14), int64(9), object(2)
# memory usage: 65.0+ KB

# %%
df.plot(kind='box', subplots=True, layout=(10, 4), figsize=(20, 60))
plt.show()

# %%
#Calculate the correlation coefficients for df
corr = df.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col1 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col2 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col4 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col5 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col7 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col9 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col10 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col11 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col12 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col13 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col14 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col15 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col16 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col17 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col18 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col19 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col20 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col21 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow0_col22 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col2 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col3 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col4 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col5 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col6 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col7 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col8 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col9 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col10 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col11 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col12 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col13 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col14 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col15 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col16 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col17 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col18 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col19 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col20 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col21 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow1_col22 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col0 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col1 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col3 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col4 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col5 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col7 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col8 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col9 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col10 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col11 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4cdd9a36_cb90_11ea_8e95_a0ceda77f56frow2_col13 {
#             background-color:  #b5cdfa;

# %%
# Removing colinear features

corr_matrix = df.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# getting the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# iterating through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',df.drop(df[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (320, 24)

# %%
df = df.drop('base_elev', axis=1)

# %%
# Now I will create clusters for analysis:

x = df.drop(['Name','state'], axis =1).values

Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
# creating three clusters

kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
# Making a new column in df dataframe called 'clusters', and assign it the variable: y_kmeans3
df['clusters'] = y_kmeans3
df.head(5)
# Out:
#                   Name    state  summit_elev  vertical_drop  trams  fastSixes  \
# 0       Alyeska Resort   Alaska         3939           2500    1.0        0.0
# 1  Eaglecrest Ski Area   Alaska         2600           1540    0.0        0.0
# 2     Hilltop Ski Area   Alaska         2090            294    0.0        0.0
# 3     Arizona Snowbowl  Arizona        11500           2300    0.0        1.0
# 4  Sunrise Park Resort  Arizona        11100           1800    0.0        0.0
#
#    fastQuads  quad  triple  double  ...  SkiableTerrain_ac  Snow Making_ac  \
# 0          2     2       0       0  ...             1610.0           113.0
# 1          0     0       0       4  ...              640.0            60.0
# 2          0     0       1       0  ...               30.0            30.0
# 3          0     2       2       1  ...              777.0           104.0
# 4          1     2       3       1  ...              800.0            80.0
#
#    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 0             150.0       60.0            669.0          65.0          85.0
# 1              45.0       44.0            350.0          47.0          53.0
# 2             150.0       36.0             69.0          30.0          34.0
# 3             122.0       81.0            260.0          89.0          89.0
# 4             115.0       49.0            250.0          74.0          78.0
#
#    projectedDaysOpen  NightSkiing_ac  clusters
# 0              150.0      550.000000         0
# 1               90.0      100.395722         0
# 2              152.0       30.000000         0
# 3              122.0      100.395722         2
# 4              104.0       80.000000         2
#
# [5 rows x 25 columns]

# %%
# Writing df dataframe to csv 
df.to_csv('data/step3_output_outliers.csv')
